# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the model architecture
model = Sequential()
num_features = 64

model.add(Conv2D(2*num_features,kernel_size=(3,3),padding='same',activation='relu',input_shape=(width, height, 1)))
model.add(Conv2D(2*num_features,kernel_size=(3,3),padding='same',activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(2*2*num_features,kernel_size=(3,3),padding='same',activation='relu'))
model.add(Conv2D(2*2*num_features,kernel_size=(3,3),padding='same',activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(2*2*2*num_features,kernel_size=(1,1),padding='same',activation='relu'))
model.add(Conv2D(2*2*2*num_features,kernel_size=(1,1),padding='same',activation='relu'))
model.add(Conv2D(2*2*2*num_features,kernel_size=(1,1),padding='same',activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(2*2*2*2*num_features,kernel_size=(1,1),padding='same',activation='relu'))
model.add(Conv2D(2*2*2*2*num_features,kernel_size=(1,1),padding='same',activation='relu'))
model.add(Conv2D(2*2*2*2*num_features,kernel_size=(1,1),padding='same',activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(2*2*2*2*2*num_features,kernel_size=(1,1),padding='same',activation='relu'))
model.add(Conv2D(2*2*2*2*2*num_features,kernel_size=(1,1),padding='same',activation='relu'))
model.add(Conv2D(2*2*2*2*2*num_features,kernel_size=(1,1),padding='same',activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999), metrics=['accuracy'])

# Define data augmentation parameters
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)

# Early stopping to prevent overfitting
es = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with data augmentation
history = model.fit(datagen.flow(train_X, train_Y, batch_size=batch_size),
                    epochs=50, 
                    validation_data=(val_X, val_Y),
                    steps_per_epoch=len(train_X) // batch_size,
                    callbacks=[es])

# Evaluate
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
